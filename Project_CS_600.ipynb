# %% [markdown]
# # Project
#
# ## Name: Hrishikesh Dinkar Kanade
#
#
# References:
# 1. https://stackoverflow.com/questions/2669059/how-to-sort-alpha-numeric-set-in-python
# 2. https://wangyy395.medium.com/implement-a-trie-in-python-e8dd5c5fde3a
# 3. https://www.geeksforgeeks.org/compressed-tries/#
# 4. Algorithm Design and Applications by Goodrich and Tamassia
# 5. ChatGPT (For clarifying concepts)
# 6. CS 600 Lecture slides
# 7. https://en.wikipedia.org/wiki/Trie
# 8. https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import os
from bs4 import BeautifulSoup as bs
import re
from collections import defaultdict
from tqdm import tqdm

# %% [markdown]
# ### Read text from the files

# %% [markdown]
# *Update the file path when running on your system*

# %%
input_folder = "C:/Users/kanad/Documents/CS 600/Project/HTML_files" # Location of HTML files

# %%
text_dictionary = {} # Dictionary format: {Webpage: text}

for fname in os.listdir(input_folder):   #iterate over files in directory
    fpath = os.path.join(input_folder, fname)
    print(f"Reading: {fpath}")
    with open(fpath, 'r', encoding='utf-8') as f:
        bs_obj = bs(f, 'html.parser')
        txt = bs_obj.get_text()
        text_dictionary[fpath] = txt
# Out:
# Reading: C:/Users/kanad/Documents/CS 600/Project/HTML_files\American_black_bear_Wikipedia.html
# Reading: C:/Users/kanad/Documents/CS 600/Project/HTML_files\Bear_Wikipedia.html
# Reading: C:/Users/kanad/Documents/CS 600/Project/HTML_files\Brown_bear_ Wikipedia.html
# Reading: C:/Users/kanad/Documents/CS 600/Project/HTML_files\Giant_panda _Wikipedia.html
# Reading: C:/Users/kanad/Documents/CS 600/Project/HTML_files\Polar_bear_Wikipedia.html
# Reading: C:/Users/kanad/Documents/CS 600/Project/HTML_files\Red_panda_Wikipedia.html

# %% [markdown]
# ## Tokenize and filter data

# %% [markdown]
# ### Tokenize

# %%
tokenized_webpages_dict ={}

for webpage, txt in text_dictionary.items():
    tokenized = re.findall(r'\b[a-zA-Z]+\b', txt.lower())
    tokenized_webpages_dict[webpage] = tokenized

# %% [markdown]
# ### Filter stopwords.
#
# Stopwords imported from NLTK and filtered from the input data

# %%
from nltk.corpus import stopwords
filter_words = set(stopwords.words('english'))

filtered_webpages_dict = {}
vocab = set()

for webpage, tokens in tokenized_webpages_dict.items():
    filtered = [word for word in tokens if word not in filter_words]
    filtered_webpages_dict[webpage] = filtered
    vocab.update(filtered)

# %%
print(f"Number of words in vocabulary: {len(vocab)}")
# Out:
# Number of words in vocabulary: 9877

# %% [markdown]
# ## Create inverted index
#
# The inverted index contains webpages the word appears in and the number of times it appears

# %%
inverted_indices = defaultdict(set)

for webpage, word in filtered_webpages_dict.items():
    seen_words=[] # maintain a seen words list to avoid repeating word count for same word
    for i in word:
        if i not in seen_words:
            inverted_indices[i].add(webpage+' '+str(word.count(i))+' instances') ## Add the webpage and count of instances for word
            seen_words.append(i)

# %%
len(inverted_indices)
# Out:
# 9877

# %% [markdown]
# ### Implement the Trie

# %%
class Comp_Trie_Node:
    def __init__(self):
        self.child_nodes = {}
        self.is_last = False
    
    def print_node(self, prefix='', indent=''):
        terminal_marker = '*' if self.is_last else ''
        if prefix:
            print(f"{indent}{prefix}{terminal_marker}")
        for edge_label, child_node in self.child_nodes.items():
            child_node.print_node(edge_label, indent + '  ')

class Compressed_Trie:
    def __init__(self):
        self.root_node = Comp_Trie_Node()
        
    def longest_common_prefix(self, string1, string2):
        minimum_length = min(len(string1), len(string2))
        i = 0
        while i < minimum_length and string1[i] == string2[i]:
            i += 1
        return string1[:i]
    
    def print_trie(self):
        print("Compressed Trie Structure:")
        self.root_node.print_node()
        
    def insert(self, word):
        node = self.root_node
        word_subword = word
        while True:
            if not word_subword:
                node.is_last = True
                return
            for prefix_label, child_item in node.child_nodes.items():
                lc_prefix = self.longest_common_prefix(prefix_label, word_subword)
                if lc_prefix:
                    if lc_prefix == prefix_label:
                        node = child_item
                        word_subword = word_subword[len(lc_prefix):]
                        break
                    else: # split edge if partial match is found
                        existing_child = child_item 
                        new_node = Comp_Trie_Node() # create a node for prefixes
                        remaining_label = prefix_label[len(lc_prefix):]
                        if remaining_label:
                            new_node.child_nodes[remaining_label] = existing_child
                            new_node.is_last = False
                        else: # new node takes existing_child's children
                            new_node.child_nodes = existing_child.child_nodes
                            new_node.is_last = existing_child.is_last

                        node.child_nodes.pop(prefix_label) ## update children of current node
                        node.child_nodes[lc_prefix] = new_node

                        remaining_word = word_subword[len(lc_prefix):] # add remainder as child
                        if remaining_word:
                            new_leaf_node = Comp_Trie_Node()
                            new_leaf_node.is_last = True
                            new_node.child_nodes[remaining_word] = new_leaf_node
                        else:
                            new_node.is_last = True
                        return
            else: # no prefix found so add word as new child
                new_leaf_node = Comp_Trie_Node()
                new_leaf_node.is_last = True
                node.child_nodes[word_subword] = new_leaf_node
                return

    def search_function(self, word): ## funstion for searching the trie
        node = self.root_node
        word_subword = word
        
        while True:
            if not word_subword:
                return node.is_last
            found_prefix = False
            for prefix_label, child in node.child_nodes.items():
                lc_prefix = self.longest_common_prefix(prefix_label, word_subword)
                if lc_prefix == prefix_label:
                    if lc_prefix == word_subword:
                        return child.is_last
                    else:
                        node = child
                        word_subword = word_subword[len(lc_prefix):]
                        found_prefix = True
                        break
                elif lc_prefix == word_subword:
                    return False
            if not found_prefix:
                return False

# %% [markdown]
# ### Create the Trie

# %%
from tqdm import tqdm
vocab_trie = Compressed_Trie()

for item in tqdm(vocab):
    vocab_trie.insert(item)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 9877/9877 [00:00<00:00, 59503.71it/s]

# %%
vocab_trie.print_trie()
# Out:
# Compressed Trie Structure:
#   c*
#     h*
#       e
#         rry*
#         z*
#         w
#           s*
#           ing*
#         n*
#           gd
#             u*
#             ong*
#         m
#           i
#             cal*
#               s*
#             stry*
#           osignals*
#         e
#           k*
#             s*
#           tah*
#         st*
#           in*
#         vron*
#       a
#         n*
#           g*
#             ing*
#             e*
#               taxa*
#               s*
#                 upload*
#           nel*
#             s*
#           ce*
#             s*
#           dra*
#         s
#           e*
#             d*
#           ing*
#         p
#           man*
#           ter*
#           ultepec*
#           a
#             lmalania*
#             rral*
#         r
#           l
#             ton*
#             es*
#             otte*
#           acter*
#             s*
#             i
#               bus*
#               z
#                 ed*
#                 ation*
#               s
#                 ed*
#                 tics*
#           ismatic*
#           coal*
#           g
#             e*
#               d*
#               s*
#             ing*
#           m*
#         us*
#           sonnet*
#         kraborty*
#         in*
#         m
#           a*
#           itataxus*
#           bers*
#         tters*
#         gas*
#       i*
#         n*
#           a*
#             hidden*
#             clawed*
#             mammals*
#             endemic*
#           quapin*
#           g*
#             a*
#           e*
#             se*
#         ef*
#           tain*
#         r
#           p*
#           iac*
#         ld*
#           ren*
#           hood*
#         c
#           ken*
#           ago*
#         m
#           panzees*
#           onobambusa*
#       lorinated*
#       o
#         colate*
#         r
#           data*
#           n*
#         ice*
#         os
#           ing*
#           e*
#             s*
#         ps*
#         l
#           esterol*
#           lima*
#       u
#         ang*
#         m*
#         en*
#         te*
#           s*
#         rch
#           es*
#           ill*
#         k
#           chi*
#           ar*
#         ff*
#           ing*
#       r
#         ysocyon*
#         o
#           mosome*
#             s*
#           togale*
#         is*
#           t
#             i*
#               n
#                 e*
#                 a*
#               an*
#                 sen*
#             o
#               doulides*
#               phe*
#                 r*
#             mas*
#       hetri*
#     o*
#       m*
#         p
#           e
#             t
#               e*
#               i
#                 t
#                   or*
#                     s*
#                   i
#                     on*
#                     ve*
#                 ng*
#             nsat
#               e*
#               ion*
#           o
#             nent*
#             sit
#               ion*
#               e*
#             und*
#               s*
#           a
#             tible*
#             r
#               tment*
#               ed*
#               ison*
#                 s*
#               a
#                 tive*
#                 ble*
#             ct*
#               ly*
#             n
#               ies*
#               y*
#           r
#             is
#               e*
#                 d*
#                 s*
#               ing*
#             e
#               ssed*
#               hensive*
#           uted*
#           tes*
#           il
#             ation*
#             ed*
#           l
#             e
#               x*
#                 it
#                   y*
#                   ies*
#                 es*
#               te*
#                 ly*
#             iment*
#         m
#           on*
#             s*
#               wikispecieswiki
#                 newswikidata*
#                 quotewikivoyagewikidata*
#                 data*
#               news*
#             ly*
#           i
#             ssion*
#               ed*
#             tte
#               e*
#               d*
#           e
#             rcial*
#               ly*
#               s*
#             n
#               ced*
#               t*
#                 s*
#           un
#             i
#               t
#                 ies*
#                 y*
#               cat
#                 e*
#                   s*
#                 ion*
#                   s*
#             al*
#               ly*
#           and*
#         b
#           in
#             ed*
#             ation*
#               staxonbars*
#             ing*
#           at*
#         te*
#         fortable*
#         e*
#           s*
#         i
#           c*
#             al*
#           ng*
#       n
#         f*
#           i
#             scated*
#             ned*
#             rm
#               s*
#               ed*
#           using*
#           ront
#             ing*
#             ed*
#             ation*
#               s*
#           l
#             ict*
#               s*
#               ing*
#             uences*
#         t
#           r
#             a
#               ct*
#               st*
#                 ed*
#                 ing*
#               ry*
#               dicts*
#             ibut
#               e*
#                 d*
#               i
#                 ons*
#                   talk*
#                 ng*
#             ol*
#               led*
#           a
#             minants*
#             in*
#               ing*
#               ed*
#             ct*
#           i
#             n
#               ent*
#                 s*
#                 al*
#               u
#                 ing*
#                 e*
#                   d*
#                 ously*
#             guous*
#           e
#             nt*
#               s*
#               ion*
#             st*
#               ed*
#             mporary*
#         s
#           t
#             ant*
#               ly*
#               ine*
#             itute*
#               s*
#               d*
#             ellation*
#               s*
#                 ofwords*
#             ruct
#               s*
#               ion*
#           i
#             der*
#               ed*
#               a
#                 tion*
#                 bl
#                   e*
#                   y*
#             st*
#               s*
#               ing*
#               e
#                 d*
#                 ntly*
#           olidated*
#           um
#             ing*
#             e*
#               s*
#               d*
#             ption*
#           e
#             rv
#               ation*
#                 ists*
#               e*
#             quences*
#           pecifics*
#         ve
#           ntion*
#             al*
#               ly*
#           r
#             sion*
#             gent*
#           yed*
#         c
#           urrent*
#           rete*
#           lu
#             sive*
#             de
#               d*
#               s*
#           e
#             al*
#             ntrat
#               ion*
#               ed*
#             ive*
#               d*
#             rn*
#             pts*
#           ave*
#           olor*
#           ha*
#         ifer*
#           ous*
#         g
#           icus*
#           re
#             ss*
#             gat
#               ions*
#               e*
#           o*
#         e*
#           s*
#           patus*
#         d
#           ition*
#             s*
#           uct*
#             ed*
#         n*
#           o
#             r*
#             tations*
#           e
#             cted*
#             ll*
#       l*
#         i*
#         o
#           cola*
#           gne*
#           n*
#             i
#               zed*
#               s
#                 ation*
#                 ts*
#             y*
#           ur*
#             s*
#             ation*
#             ed*
#           mbian*
#           r*
#             a
#               tion*
#               do*
#             ed*
#             s*
#         a*
#         l
#           e
#             ge*
#             ct
#               ed*
#               i
#                 on*
#                   s*
#                 ng*
#                 vely*
#               ors*
#           ar*
#             ed*
#             is*
#           i
#             sions*
#             ns*
#             de*
#         umbia*
#         d*
#           er*
#         e
#           bourn*
#           y*
#       u
#         gar*
#           s*
#         r
#           age*
#           t
#             ney*
#             ship*
#             ing*
#             esy*
#           se*
#         ple*
#           s*
#         n
#           t
#             er
#               parts*
#               ed*
#             y*
#             r
#               ies*
#               y*
#             ies*
#           cil*
#         l
#           son*
#           d*
#       a
#         rse*
#           ns*
#         st*
#           al*
#           line*
#         t*
#           i*
#             s*
#           ed*
#           s*
#         lition*
#       r
#         on
#           avirus*
#           ets*
#         umictis*
#         dial*
#         poration*
#         r
#           e
#             late*
#               s*
#             ct*
#             spond
#               ing*
#                 ly*
#               s*
#           idor*
#             s*
#         ms*
#         bet*
#           t*
#         sac*
#         n*
#         tic
#           osteroid*
#           al*
#         i*
#         e*
#       exist*
#         e
#           d*
#           nce*
#         s*
#       o
#         per*
#           ation*
#         gan*
#         k
#           i
#             ng*
#             e*
#           ed*
#         l*
#       c
#         a*
#         cidia*
#         hrane*
#         k*
#           ed*
#           atrice*
#       w*
#         an*
#         s*
#       p
#         enhagen*
#         y*
#         i
#           es*
#           ng*
#         per*
#         ulati
#           ng*
#           on*
#       he
#         sive*
#         n*
#       gniti
#         on*
#         ve*
#       ver*
#         age*
#         ed*
#         ing*
#       yote*
#         s*
#       s
#         t*
#           s*
#         m
#           ic*
#           etic*
#             s*
#         ewic*
#       d
#         ing*
#         e*
#       xon*
#       in*
#         cide
#           nt*
#           s*
#         s*
#         ed*
#       zumel*
#       bi*
#     a*
#       l
#         f*
#         iforni
#           cus*
#           a*
#             hidden*
#             n*
#               us*
#           ensis*
#         l*
#           ing*
#           s*
#           o
#             sa*
#             rhinus*
#           ed*
#         v
#           es*
#           ignac*
#         c
#           i
#             ned*
#             um*
#           utta*
#       n
#         vasback*
#         opy*
#         yon*
#         crivorus*
#         t
#           abria*
#             n*
#           ing*
#           on*
#             ese*
#         i
#           d*
#             ae*
#             s*
#           s*
#           n
#             e*
#               s*
#             i*
#             o*
#             a*
#           form
#             ia*
#             s*
#           martes*
#         n
#           ibalism*
#           adine*
#           ot*
#         didate*
#           s*
#         a*
#           d
#             ensis*
#             a*
#               mammals*
#               the*
#             ian*
#         escens*
#         s*
#       xton*
#       ges*
#       c
#         tus*
#         omistle*
#         h
#           es*
#           ing*
#       r*
#         bon*
#         o*
#           l
#             i*
#               n
#                 e*
#                 a*
#                   s*
#             yn*
#         t
#           a*
#           oon*
#             s*
#         a*
#           cal*
#             lineage*
#         pathians*
#         n
#           ivor
#             e*
#               s*
#             a*
#               morphans*
#               n*
#                 s*
#                   pliocene*
#                   quaternary*
#             ous*
#             y*
#           a
#             tion*
#             ssial*
#               s*
#         e*
#           d*
#           er*
#         l*
#           stead*
#           ottae*
#         m
#           el*
#           ichael*
#         d
#           all*
#           s*
#         r
#           i
#             on*
#             e
#               d*
#               s*
#           y*
#         v
#           ing*
#           ed*
#         c
#           ass*
#             es*
#           inophagus*
#         i
#           ta*
#           bou*
#       s
#         seroles*
#         e*
#           s*
#         t
#           anopsis*
#           ellanos*
#         pi
#           an*
#           ca*
#       t*
#         lineage*
#           pardofelis*
#         fish*
#         herine*
#         alan*
#         ch*
#           ing*
#           es*
#         opuma*
#         egor
#           i
#             es*
#             zed*
#           y*
#         us*
#         t
#           le*
#           on*
#         s*
#       m*
#         e*
#           ra*
#           lopard*
#         p
#           grounds*
#           bell*
#           us*
#           aign*
#         s*
#         ouflage*
#         arra*
#         b
#           ridge*
#           i
#             llau*
#             um*
#       ecum*
#       p
#         stone*
#         t
#           iv
#             e*
#             ity*
#           ure*
#             d*
#         i
#           llaria*
#           ta
#             n*
#             l*
#         a
#           city*
#           b
#             ility*
#             le*
#         e*
#           nsis*
#       v*
#         e*
#           rnous*
#           ndish*
#           s*
#         it
#           y*
#           ies*
#       b
#         rales*
#         i*
#       i*
#         wu*
#       o*
#       u
#         s
#           e*
#             s*
#             d*
#           ing*
#         ght*
#         casian*
#         rina*
#       d
#         ency*
#         man*
#       hill*
#     u*
#       ja*
#       l
#         t*
#           ur
#             e*
#               s*
#             al*
#           ivating*
#         minating*
#         verts*
#         p
#           aeus*
#           eo*
#       t*
#         e*
#         worm*
#         s*
#         ting*
#       isine*
#       nning*
#       r
#         one*
#         tis*
#         ve*
#           s*
#           d*
#         le
#           d*
#           y*
#         r
#           y*
#           ent*
#             ly*
#           icul
#             a*
#             um*
#         io
#           us*
#           sity*
#       vier*
#         edge*
#       b*
#         s*
#           cub*
#       es*
#         ta*
#       cphuongensis*
#       s
#         p
#           idata*
#           s*
#           ed*
#         tomers*
#       m*
#       on*
#       ddly*
#     r
#       o
#         p*
#           s*
#         atia*
#           n*
#         w*
#           theri*
#           n*
#             s*
#             ed*
#         zier*
#         ss*
#           breeding*
#           archus*
#           ing*
#           roads*
#         cuta*
#         uch
#           es*
#           ing*
#       e
#         a
#           m*
#           t
#             e*
#               s*
#               d*
#             ure*
#               s*
#             or*
#             i
#               ve*
#               ng*
#               on*
#         e*
#           ks*
#         taceous*
#         s
#           cent*
#           po*
#           t*
#             ed*
#         vice*
#           s*
#         puscular*
#         ciente*
#       y*
#         stal*
#         pt
#           oprocta*
#           i
#             c*
#             d*
#       u
#         el*
#         m*
#           p*
#         sh*
#           ed*
#           ing*
#         de*
#         zi*
#       i
#         minals*
#         tical*
#           ly*
#         der*
#         es*
#         st
#           ina*
#           ata*
#       a
#         ssicauda*
#         ni
#           al*
#           odental*
#         terogale*
#         wl*
#         paudy*
#         b*
#           be*
#           s*
#           eater*
#         ig*
#           head*
#         mped*
#       c*
#       vi*
#     l
#       a
#         udia*
#         r
#           os*
#           k*
#             son*
#           if
#             y*
#             i
#               cation*
#               e
#                 d*
#                 s*
#           endon*
#         im*
#           ed*
#         w*
#           ing*
#           less*
#           s*
#           ed*
#         ss*
#           ed*
#           ses*
#           i
#             cal*
#             f
#               i
#                 cation*
#                 ed*
#               y*
#         p
#           ham*
#           ping*
#         ttering*
#         ms*
#         d
#           e*
#             s*
#           ogram*
#       i
#         o*
#         cking*
#         m
#           b*
#             ing*
#             er*
#               s*
#           ate*
#             s*
#         n
#           tock*
#           ical*
#         ffs*
#         p
#           s*
#           ped*
#       u
#         b*
#         msily*
#         ster*
#           s*
#         ff*
#         es*
#         te*
#       ear*
#         cutting*
#         ly*
#       o
#         vis*
#         uded*
#         ck*
#         s
#           e*
#             st*
#             ly*
#             r*
#             d*
#           tridium*
#         thing*
#         ned*
#     e
#       ased*
#       dar*
#       r
#         docyon*
#           ina*
#         nictis*
#         tain*
#         e
#           monies*
#           zo*
#       phalogale*
#       l
#         l*
#           ulose*
#           ed*
#           s*
#         rep*
#         e
#           br
#             ates*
#             ity*
#           ste*
#         t
#           s*
#           ic*
#       n
#         t*
#           ur
#             ies*
#             y*
#           e
#             nnial*
#             r*
#           r
#             al*
#             e*
#               s*
#         ozoic*
#       tacean*
#       iling*
#       cum*
#     i
#       v
#         et*
#           t
#             a*
#             i
#               ctis*
#               na*
#           one*
#         i
#           c*
#           l*
#       ochon*
#       t
#         y*
#         e*
#           d*
#           s*
#             eerx*
#         ation*
#           s*
#         i
#           es*
#           zenship*
#       n
#         namo
#           mum*
#           n*
#             um*
#         e
#           re
#             a*
#             oargenteus*
#             us*
#           ma*
#       rc
#         les*
#         a
#           mustela*
#           dian*
#         u
#           la
#             r*
#             t
#               ion*
#               ory*
#           s*
#             es*
#           mpolar*
#       ucci*
#       esielski*
#     y
#       n
#         ogale*
#         ictis*
#       cle*
#         s*
#       stophora*
#       rn
#         aonyx*
#         olutra*
#       anide*
#       onasua*
#     dv*
#     m*
#     b
#       s*
#       ba*
#     nn*
#     s*
#     fn*
#   b*
#     i*
#       o
#         assays*
#         stratigraphy*
#         diversity*
#         engineering*
#         l
#           og
#             y*
#               polar*
#             i
#               ca*
#                 l*
#               es*
#               sts*
#           ib*
#         mechanic
#           s*
#           al*
#         t
#           a*
#           echnology*
#         c
#           hemi
#             stry*
#             cal*
#           on*
#       n*
#         inda*
#         ky*
#         turong*
#         ding*
#         bin*
#         g*
#         o
#           tata*
#           mial*
#       r
#         ch*
#         d*
#           s*
#             eed*
#         th*
#           rate*
#           day*
#           s*
#       phenyl*
#       colored*
#       s
#         on*
#         sell*
#         ta*
#         c
#           ione*
#           uits*
#           hof*
#       t
#         s*
#         ing*
#         e*
#           s*
#           force*
#         te
#           r*
#             ness*
#           n*
#       kol*
#       e
#         ti*
#         sen*
#         l*
#         der*
#       b
#         liography*
#         code*
#       g*
#         g
#           s*
#           e
#             st*
#             r*
#         horn*
#       l
#         e*
#         li
#           ngs*
#           ons*
#       don*
#       a
#         n*
#         rd*
#     u
#       s
#         h*
#           y*
#           es*
#         k
#           er*
#           ing*
#         ch*
#         ting*
#         iness*
#       r
#         ns*
#         sts*
#         ford*
#         row
#           s*
#           ing*
#         ying*
#         mese*
#         hans*
#         gher*
#         kert*
#         i
#           als*
#           ed*
#       l
#         k*
#           y*
#         garia*
#         bs*
#         l*
#           etin*
#       d
#         s*
#         orcas*
#         gets*
#         d
#           hist*
#           i*
#       ck
#         ingham*
#         ley*
#       il
#         d*
#           s*
#           ing*
#         t*
#       ff*
#         alo*
#         on*
#       tte*
#       nne
#         feld*
#         ll*
#       m
#         deling*
#         thang*
#     r
#       b*
#       a
#         siliensis*
#         n
#           igan*
#           ch*
#             e
#               d*
#               s*
#         uron*
#         chy
#           p
#             rotoma*
#             salis*
#           ur
#             a*
#             us*
#         mble*
#         d
#           ely*
#           ley*
#         in*
#           s*
#         y*
#         ve*
#           ry*
#       o
#         ught*
#         ad*
#           l
#             eaf*
#             y*
#           casting*
#           e
#             r*
#             st*
#         w
#           n*
#             ish*
#             e*
#           s*
#             er*
#             ing*
#         o
#           d*
#           k*
#             s*
#         meliads*
#         n
#           ze*
#           x*
#         ther*
#       i
#         stoli*
#         an*
#         t
#           a
#             in*
#             nnica*
#           ish*
#         n
#           g*
#             s*
#           k*
#         e
#           n*
#           f*
#         d
#           egroom*
#           ge*
#         g
#           ht*
#           gs*
#       e
#         a
#           k*
#             down*
#             ing*
#             up*
#             s*
#           th*
#             ing*
#           st*
#           ch*
#             ed*
#         ed*
#           ers*
#           ing*
#         nda*
#         vimalictis*
#         d*
#       glez*
#       u*
#         n*
#           berg*
#           ne
#             a*
#             r*
#           ton*
#           swick*
#         sh*
#         un*
#         ce*
#         yn*
#         in*
#       yan*
#       scic*
#     o*
#       cherens*
#       o
#         thia*
#         k*
#           plate*
#           s*
#         nstra*
#         m*
#           s*
#       essenecker*
#       r*
#         d
#           er*
#             lands*
#           ure*
#         rowed*
#         n*
#           e
#             o*
#             an*
#         inda*
#         eas*
#       l
#         d*
#         shakov*
#         t
#           unov*
#           ed*
#       y
#         d*
#         s*
#         koff*
#       b
#         rov*
#         cat*
#           s*
#         by*
#         white*
#       w*
#         hunter*
#           s*
#         s*
#         en*
#         yer*
#       d
#         ner*
#         i
#           ly*
#           e
#             d*
#             s*
#         onia*
#         y*
#       u
#         n
#           d
#             ar
#               ies*
#               y*
#             ing*
#           t
#             ies*
#             y*
#         t*
#         r
#           lon*
#             i*
#           ton*
#           chier*
#       mbieri*
#       n
#         ser*
#         d*
#           ed*
#           archuk*
#         e*
#           nfant*
#           s*
#         y*
#         is*
#         ariense*
#       itani*
#       vids*
#       a
#         r*
#           d*
#             s*
#         ts*
#       s
#         tock*
#         son*
#       t
#         t
#           om*
#           lenecks*
#         an
#           ical*
#           y*
#     e
#       g
#         in*
#           ning*
#           s*
#         an*
#       c
#         ame*
#         k*
#           mann*
#           er*
#         ome*
#           s*
#         hshoft*
#       a
#         ches*
#         ts*
#         st*
#           s*
#         r*
#           s*
#             kin*
#             extant*
#             species*
#             carnivorans*
#             holarctic*
#             fur*
#             t
#               emporal*
#               udy*
#           ded*
#           ing*
#           biology*
#           t
#             emporal*
#             hree*
#         u
#           fort*
#           val*
#       r
#         ing*
#           ia*
#             n*
#               us*
#         t
#           ram*
#           a*
#         n*
#           ard*
#           d*
#           hard*
#             t*
#         lin*
#         r
#           ies*
#           y*
#         g
#           man*
#             n*
#           er*
#         e
#           zkin*
#           czky*
#         a*
#           rdinelli*
#         keley*
#       doya*
#       n*
#         e
#           volent*
#           fi
#             t*
#               s*
#             cial*
#         gal*
#           ensis*
#         d*
#         veniste*
#         n*
#           y*
#           ett*
#             ii*
#         jamin*
#       l
#         l*
#           y*
#           ied*
#           emain*
#           ows*
#         ant*
#         i
#           n*
#           e
#             f*
#             ve*
#               d*
#           kov*
#         uga*
#           s*
#         o
#           ng*
#             s*
#           ved*
#         t*
#       h
#         ind*
#         eco*
#         avio
#           r*
#             al*
#             s*
#           ur*
#             al*
#             s*
#         rend*
#       e*
#         hive*
#           s*
#         ch*
#           am*
#         r*
#         f*
#         tles*
#         s*
#           t*
#       i*
#         jing*
#       t
#         h*
#         ter*
#         sy*
#       zant*
#       s
#         t*
#         palova*
#         ides*
#       o
#         grad*
#         wulf*
#       y
#         ond*
#         er*
#     a
#       r*
#         yshnikov*
#         k*
#           er*
#           s*
#           ing*
#         a
#           nogale*
#           l*
#           gona*
#         s*
#         on*
#         ents*
#         low*
#         r
#           ier*
#           e
#             l*
#             tt*
#             n*
#           ows*
#         clay*
#         un*
#         ter*
#         b
#           er
#             a*
#             ries*
#           a
#             tus*
#             ra*
#           ie*
#         ne
#           tt*
#           s*
#       y*
#         ous*
#         s*
#         l
#           or*
#           isascari
#             s*
#             asi*
#         esian*
#       wl*
#       s
#         i*
#           s*
#           c*
#             ranial*
#           n*
#           lisk*
#         al*
#         sari
#           scus*
#           cy
#             on*
#             noides*
#         e*
#           d*
#         tian*
#         u*
#         h
#           ir*
#           ania*
#       c
#         teria*
#           l*
#         k*
#           tracking*
#           ed*
#           s*
#             catter*
#             ide*
#           ground*
#         hmann*
#         on*
#       u
#         man*
#         tista*
#       o*
#       i*
#         ting*
#         kal*
#         ley*
#       n
#         ks*
#         d
#           s*
#           ing*
#           ed*
#         gs*
#         ne
#           d*
#           r*
#         yue*
#       gged*
#       mb
#         oo*
#           s*
#           zled*
#         us
#           oideae*
#           eae*
#       d
#         ia*
#         ge*
#           r*
#             s*
#       l
#         ance*
#         timore*
#         d*
#         ouskus*
#         l*
#           s*
#       xter*
#       t*
#       b
#         y*
#         u*
#       ker*
#       ffin*
#     l
#       a
#         me*
#         ck*
#           well*
#         n
#           c*
#           kets*
#           ford*
#         z
#           on*
#           e*
#         d
#           es*
#           ders*
#         tting*
#         ke*
#         ire*
#       o
#         g*
#         ssoms*
#         od*
#           ed*
#           s
#             tream*
#             hed*
#         w*
#           s*
#           ing*
#         nde*
#       ind*
#         ness*
#       u
#         nt*
#         e*
#         bber*
#       e
#         u*
#         nding*
#         at*
#           ing*
#           s*
#         isch*
#     b*
#       af*
#       c*
#       fa*
#     mc*
#     c*
#     s*
#     deogale*
#     p*
#     f
#       aeat*
#       q*
#     h
#       utan*
#         mammals*
#       attacharya*
#   p*
#     l
#       os*
#       a
#         usible*
#         ce*
#           ment*
#           d*
#           s*
#           n
#             ames*
#             tal*
#         y*
#           ed*
#           houses*
#           s*
#           ing*
#         t
#           ycephalus*
#           form*
#             s*
#           e
#             s*
#             au*
#         n*
#           ning*
#           t*
#             s*
#             ers*
#             igrade*
#           iceps*
#           et*
#             ary*
#         ins*
#         s
#           ma*
#           ticity*
#         zi*
#       e
#         xiglass*
#         asure*
#         s
#           sis*
#           i
#             o
#               g
#                 ale*
#                 ulo*
#               meles*
#             ctis*
#         i
#           ades*
#           stocene*
#       u
#         g*
#           s*
#         sh*
#         nges*
#       i
#         o
#           cene*
#           taxidea*
#           n
#             ictis*
#             arctos*
#         thocyon*
#     r
#       e*
#         ziosi*
#         s
#           s*
#             ure*
#             ed*
#           trud*
#           e
#             rv
#               ation*
#               e*
#               ing*
#             n
#               t*
#               ce*
#           i
#             ctis*
#             den
#               t*
#               cy*
#           um
#             ed*
#             ably*
#           c
#             ribed*
#             hool*
#         v
#           ious*
#             ly*
#           ent*
#             i
#               on*
#               ng*
#           alen
#             t*
#             ce*
#         fer*
#           r
#             ed*
#             ing*
#           s*
#           ence*
#             s*
#         d
#           omina
#             te*
#             n
#               tly*
#               ce*
#           at
#             e*
#             ion*
#             or*
#               y*
#               s*
#           ict*
#             i
#               ng*
#               ons*
#             s*
#             ed*
#         y*
#           s*
#           ed*
#           ing*
#         ocupant*
#         p
#           oecilogale*
#           ar
#             ation*
#             e*
#         gnan
#           t*
#           c
#             ies*
#             y*
#         molars*
#         h
#           ensile*
#           istoric*
#         c
#           ursor*
#           ise*
#       o*
#         v
#           en*
#           i
#             sion*
#               ally*
#                 u*
#             d
#               ing*
#               e*
#                 d*
#                 s*
#             nc
#               e*
#                 s*
#               ial*
#           o
#             cax*
#             king*
#         c
#           tor*
#           yon*
#             id*
#               s*
#               ae*
#             oides*
#           e
#             edings*
#             ss*
#               ing*
#         gr
#           ess*
#             es*
#           am*
#             s*
#             me*
#               s*
#         m
#           ote*
#             d*
#           e
#             phitis*
#             l
#               livora*
#               es*
#           i
#             nent*
#               ly*
#             scu
#               ity*
#               ous*
#           artes*
#         t
#           e
#             ct*
#               s*
#               i
#                 on*
#                 ve*
#               ed*
#             in*
#               s*
#             omic*
#             les*
#             sts*
#             us*
#           ursus*
#           o*
#             procyon*
#             zoa*
#               n*
#                 s*
#           ru
#             ding*
#             sible*
#         ject*
#           ions*
#           ed*
#           s*
#         of*
#         se*
#         hibit*
#           ed*
#         b
#           lem*
#             atic*
#             s*
#           a
#             b
#               l
#                 e*
#                 y*
#               ility*
#             ssariscus*
#         zac*
#         p
#           utorius*
#           o
#             rtion*
#               a
#                 lly*
#                 tely*
#             se
#               d*
#               s*
#           er*
#             ly*
#             ty*
#         xim
#           ate*
#           ity*
#         n
#           e*
#           ghorn*
#           ounced*
#         l
#           if
#             ic*
#             erat
#               ion*
#               ed*
#           onged*
#         d
#           uc
#             t*
#               s*
#               i
#                 vity*
#                 on*
#             e*
#               d*
#             ing*
#           romus*
#         fi
#           t*
#           le*
#             s*
#       a
#         ctice*
#           s*
#         i
#           se*
#             d*
#           rie*
#             s*
#         panya*
#         d
#           han*
#           esh*
#         y*
#         japati*
#       i
#         bilof*
#         s
#           on*
#           tin
#             us*
#             ailurus*
#           cus*
#         va
#           cy*
#           te*
#             ly*
#         n
#           c
#             ipal*
#               ly*
#             e*
#               ton*
#               ss*
#           t*
#             ed*
#         m
#           e*
#           itive*
#           ar
#             y*
#             ily*
#         o
#           nailurus*
#           r*
#             it
#               ized*
#               y*
#         c
#           e*
#           kly*
#       c*
#       u
#         ssia*
#         inosus*
#       zepaska*
#     o
#       r
#         k*
#         t*
#           al*
#             recent*
#             s*
#           cullis*
#           rayed*
#           ion*
#           er*
#         osity*
#         n*
#       s
#         e*
#           d*
#         s
#           ess*
#           ib
#             l
#               e*
#               y*
#             ilit
#               ies*
#               y*
#         it
#           i
#             ve*
#               ly*
#             on*
#               s*
#               ed*
#           ed*
#         t*
#           ma*
#           cards*
#           glacial*
#       kes*
#       cono*
#         s*
#       l
#         l*
#           ock*
#           ut
#             ants*
#             ion*
#         y
#           nyas*
#           gyny*
#           chlorinated*
#         i
#           tic
#             al*
#               ly*
#             s*
#           cy*
#         a
#           r*
#             is*
#           nd*
#         e*
#           cat*
#             s*
#       u
#         sargues*
#         n
#           ce*
#             d*
#           d*
#             s*
#         ches*
#         d
#           el*
#           yal*
#       p*
#         escu*
#         s*
#         ula
#           r*
#             ity*
#             ly*
#           tion*
#             s*
#         ping*
#       e
#         nsis*
#         cil
#           ogale*
#           ictis*
#       t
#         assium*
#         os*
#         ent*
#           ial*
#             ly*
#             s*
#       n
#         e*
#         ya*
#         gracz*
#       ac
#         h*
#           ing*
#           ed*
#         eae*
#       we
#         r*
#           s*
#           ed*
#           ful*
#         ll*
#       o
#         r*
#           er*
#         h*
#         l*
#           e*
#       i
#         nt*
#           ed*
#         soning*
#     a
#       d*
#         maja*
#         s*
#         d
#           ington*
#           l
#             ing*
#             e*
#       w*
#         s*
#       r
#         oligobunis*
#         t*
#           s*
#           ner*
#           y*
#           ridge*
#           ly*
#           i
#             c
#               ipates*
#               ular*
#                 ly*
#             ally*
#             ngton*
#         v
#           ula*
#           o
#             rder*
#             virus*
#         c*
#         a
#           cynictis*
#           taxidea*
#           lutra*
#           brachypsalis*
#           p
#             hyly*
#             otos*
#           ilurus*
#           hyaen
#             odon*
#             a*
#           doxur
#             inae*
#             us*
#           s
#             it
#               e*
#                 s*
#               ology*
#               i
#                 c*
#                 zed*
#             pecies*
#           gale*
#           m
#             yxovirus*
#             etersall*
#           nasua*
#         k*
#           s*
#         ent
#           al*
#           s*
#           ing*
#         sons*
#         d
#           i
#             n
#               e*
#               us*
#               a*
#             color*
#           us*
#           alis*
#           y*
#         i
#           ctis*
#           s*
#           js*
#       n*
#         oramic*
#         pan*
#         chthar*
#         g*
#           chen*
#           olakha*
#         nonictis*
#         da*
#           s*
#             panda*
#             mammals*
#           temporal*
#         ama*
#         th
#           e
#             r*
#               inaeneofelis*
#               a*
#             on*
#           i*
#       s
#         s
#           age*
#             s*
#           e
#             s*
#             d*
#         t*
#           ures*
#           or*
#             alists*
#             ino*
#         o*
#         itschniak*
#       i
#         r*
#           s*
#           ed*
#           ings*
#         sley*
#         nt
#           ing*
#             s*
#           ed*
#       t*
#         agoni
#           an*
#           cus*
#         h
#           s*
#           o
#             gens*
#             log
#               ical*
#               y*
#           ways*
#         ou*
#         tern*
#           s*
#         ch*
#           es*
#         r
#           o
#             l*
#             nage*
#           ick*
#       g
#         e*
#           s*
#             wikipedia*
#             good*
#             use*
#             articles*
#             permanent*
#             featured*
#           get*
#           contentscurrent*
#         ophil
#           ic*
#           us*
#         uma*
#         ano*
#       l
#         m*
#           qvist*
#         a
#           wan*
#           eo
#             ntology*
#             ecological*
#             me
#               les*
#               phitis*
#           siatica*
#           dino*
#         l*
#           ida*
#           as*
#             ursus*
#         e*
#           o
#             ntolog
#               ical*
#               y*
#             lithic*
#             biolog
#               y*
#               ical*
#             genome*
#         ud
#           inosus*
#           olutra*
#       y*
#       c
#         k*
#           s*
#         hyphyllus*
#         i
#           ng*
#           fic*
#         e*
#       kistan*
#       etkau*
#       u
#         l*
#         del*
#         city*
#       o*
#         lo*
#       mp
#         ean*
#         as*
#       x*
#       v
#         ilion*
#         el*
#       p
#         al*
#         e*
#           r*
#       zetnov*
#     e
#       n
#         g*
#         teriani*
#         i
#           cillata*
#           nsula*
#             r*
#         n
#           y*
#           sylvania*
#           ant*
#             i*
#         jor*
#       l
#         ycictis*
#         ican*
#         t*
#           on*
#           s*
#         letier*
#         age*
#         vis*
#         osi*
#       r*
#         niger*
#         s
#           ist*
#             ing*
#             e
#               d*
#               nt*
#           on
#             a
#               ta*
#               l*
#                 ly*
#                 ities*
#             ification*
#           eus*
#           p
#             ective*
#             icillata*
#         unium*
#         vasive*
#         form*
#           ing*
#           ances*
#           ed*
#         ce
#           ption*
#           nt*
#             ages*
#           ived*
#         rin*
#         egusna*
#         ma
#           nent*
#             ly*
#           frost*
#         i*
#           pheral*
#           od*
#             s*
#           shing*
#         ha
#           ps*
#           m*
#       a
#         k*
#           ed*
#           s*
#         n*
#         r*
#           son*
#           c
#             e*
#             h*
#         c
#           ock*
#           e*
#             ful*
#       derson*
#       t*
#         s*
#         er*
#           s*
#             on*
#         roglyphs*
#         ter*
#       quot*
#       ople*
#         s*
#       p
#         tides*
#         per*
#       yton*
#       s
#         sier*
#         avento*
#         ticides*
#       e
#         l*
#         rj*
#       c
#         o
#           s*
#           n*
#         uliar*
#       kania*
#       ignictis*
#       g
#         asus*
#         tymel*
#     i
#       qued*
#       oneer*
#         s*
#       scivora*
#       r
#         ineus*
#         ro*
#         ate*
#       n*
#         g*
#         k*
#         tail*
#         s*
#         y
#           in*
#           on*
#         niped*
#           s*
#           ia*
#         point*
#           s*
#         e*
#       g*
#         s*
#         ment*
#         eon*
#       peridinone*
#       acenzian*
#       e
#         tsch*
#         rre*
#         ce*
#           s*
#       x
#         yjack*
#         iu*
#         ar*
#       t*
#         s*
#         t
#           sburgh*
#           ed*
#       mm*
#       c
#         tu
#           s*
#           res*
#         os*
#         k*
#       ke*
#       le*
#     h*
#       y
#         s
#           i
#             cal*
#             olog
#               ical*
#               y*
#           aloptera*
#         cologia*
#         l
#           oge
#             n
#               y*
#               etic*
#                 s*
#             ograph
#               y*
#               ic*
#           lostachys*
#           um*
#       d*
#       o
#         berocyon*
#         c
#           a*
#             rctos*
#           oidea*
#           i
#             n
#               ae*
#               i*
#             dae*
#         sphorites*
#         enix*
#         to
#           graph*
#             ic*
#             s*
#           s*
#       e
#         asant*
#           s*
#         romone*
#           s*
#       i
#         pps*
#         l
#           ip*
#             p
#               e*
#               ii*
#           adelphia*
#       a
#         se*
#         leristics*
#         rynx*
#       r
#         ase*
#           s*
#             articles*
#         umsengla*
#       p*
#     u
#       r
#         su
#           e*
#           i
#             vant*
#             ng*
#             t*
#         p
#           le*
#           ose*
#             ly*
#           ure*
#       s
#         illus*
#         a*
#         hed*
#       p*
#         ae*
#         s*
#       ma*
#         lineageacinonyx*
#         s*
#       das*
#       bli
#         c*
#           ations*
#           mind*
#         sh
#           ing*
#           e
#             rs*
#             d*
#       ck*
#         e
#           tt*
#           red*
#       l
#         l*
#           s*
#           man*
#         sing*
#         verulenta*
#       gnax*
#       ncture*
#       t*
#         ative*
#         orius*
#     y
#       gm
#         y*
#         ae
#           a*
#           us*
#       r
#         amid*
#         en
#           aicus*
#           ees*
#         y*
#       ctis*
#     df*
#       printable*
#     p*
#       olci*
#     t
#       eronura*
#       armigan*
#       olemy*
#     s
#       ychological*
#       eudogen
#         isation*
#         e*
#       p*
#     fenninger*
#     m
#       id*
#       c*
#     c
#       nt*
#       bs*
#     g*
#       en*
#     n
#       as*
#       eumonia*
#         e*
#     jz*
#   h*
#     u*
#       ff*
#         s*
#         ing*
#       n
#         dreds*
#         t*
#           s*
#           ing*
#           e
#             d*
#             r*
#               s*
#                 waterfowl*
#         g
#           ry*
#           arian*
#           er*
#             ford*
#       i*
#       ber*
#       sbandry*
#       m*
#         an*
#           s*
#         id*
#         ming*
#         p*
#         boldt*
#           ii*
#         le*
#       a*
#         sbt*
#         ng*
#       e
#         ttmann*
#         s*
#       g
#         ging*
#         e*
#         h*
#           es*
#       o*
#       ck
#         leberries*
#         ins*
#       l
#         bert*
#         l*
#       dson*
#     y
#       p
#         othes
#           i
#             zed*
#             s*
#           es*
#         er
#           phagia*
#           carnivore*
#       ena*
#         s*
#       brid*
#         s*
#         ization*
#           s*
#       strix*
#       a
#         en
#           inae*
#           a*
#         des*
#       d
#         er*
#         r
#           urga*
#           ictis*
#     e
#       r
#         b
#           al*
#           ivor
#             es*
#               endangered*
#               herbivorous*
#             y*
#             ous*
#         ald*
#           ry*
#         d
#           s*
#           ing*
#           er*
#             s*
#         r
#           in*
#           er
#             o*
#             a*
#         tfordshire*
#         ma
#           phroditus*
#           n*
#         e
#           dity*
#           related*
#         itage*
#         p
#           est
#             es*
#             i
#               dae*
#               nae*
#             oidea*
#               hyaenidae*
#           ailurus*
#       l
#         en*
#         p*
#           ed*
#           le
#             ss*
#             arn*
#           s*
#           ing*
#         l
#           abrunn*
#           er*
#         arctos*
#         ogale*
#         m*
#           et*
#         ictidinae*
#         d*
#           meier*
#       g
#         ab*
#         elund*
#       a
#         d*
#           s*
#           ed*
#         r*
#           d*
#           ing*
#           t*
#             edly*
#         l*
#           ing*
#           th*
#             y*
#             ier*
#         t*
#           her*
#         v
#           i
#             er*
#             ly*
#           y*
#       emskerk*
#       m
#         locks*
#         i
#           n*
#           c
#             yoni
#               nae*
#               dae*
#             elluloses*
#           sphere*
#           galus*
#         stock*
#       i
#         n
#           tzman*
#           emann*
#           iger*
#         di*
#         ght*
#         ss*
#         ko*
#       n
#         sel*
#         g*
#           duan*
#         r
#           ik*
#           y*
#         eage*
#         ce*
#         drix*
#       dman*
#       p
#         tner*
#         atitis*
#     o
#       r
#         atio*
#         n*
#           ocker*
#           e*
#           joserbscehrvatski
#             idobahasa*
#             bahasa*
#         mone*
#           s*
#         se*
#           back*
#           s*
#         ribilis*
#       u*
#         nd*
#           s*
#         r*
#           s*
#         s
#           ing*
#           e*
#             s*
#             d*
#       wever*
#       n
#         g*
#           ning*
#           mei*
#           bo*
#           y
#             an*
#             u*
#         ks*
#         e*
#           y*
#             combs*
#         tecillas*
#         o
#           r*
#           ur*
#       ckett*
#       t*
#       o
#         k
#           ing*
#           e
#             d*
#             ri*
#         ves*
#         t
#           ing*
#           s*
#         ded*
#       l
#         l
#           y*
#             wood*
#           ow*
#             ed*
#         e*
#           s*
#         d*
#           s*
#           ing*
#         ocene*
#         mes*
#       kkaido*
#       s
#         pitalized*
#         t*
#           s*
#           ile*
#         e*
#           i*
#       me*
#       htola*
#       g*
#       ary*
#       p
#         kins*
#         ing*
#         e*
#           well*
#         lictis*
#       evenii*
#       b
#         oken*
#         son*
#       f
#         fman*
#           n*
#         reiter*
#     a*
#       n*
#         n
#           a*
#             h*
#           i*
#         d*
#           outs*
#           s*
#             ome*
#           book*
#           lers*
#         s*
#           en*
#           sen*
#         ging*
#       r
#         a*
#           ss*
#         low*
#         r
#           y*
#           i
#             ngton*
#             s*
#               on*
#           ell*
#         d*
#           y*
#           ened*
#           cover*
#           w
#             ood*
#               s*
#             icke*
#         m*
#         bo
#           r*
#           ur*
#         p*
#           oon*
#           er*
#             collins*
#           y*
#         vest*
#           ing*
#           ed*
#         tmann*
#         oldson*
#         e*
#         ington*
#         sh*
#           er*
#       cklaender*
#       m
#         dine*
#         pton*
#         mond*
#         s*
#         burg*
#         ade*
#         iltoni*
#         er*
#       i
#         r*
#           y*
#           s*
#           ier*
#           less*
#         d
#           a*
#             rum*
#           er*
#         le
#           d*
#           r*
#       l*
#         f*
#         l*
#           strom*
#           oran*
#         ichoerus*
#       t
#         s*
#         ch
#           ing*
#           ment*
#       bit
#         at*
#           s*
#           ions*
#         s*
#         ua
#           ted*
#           lly*
#       k*
#         ala*
#       u
#         dio*
#         sa*
#         l*
#           ing*
#       ppen*
#         s*
#         ed*
#       s
#         egawa*
#         sanin*
#         tings*
#       ddad*
#       g
#         liaqtug*
#         e
#           y*
#           nbeck*
#       z
#         zah*
#         elnuts*
#       w
#         es*
#         aiian*
#       yden*
#     i
#       n
#         ges*
#         d*
#           feet*
#           l
#             imb*
#               s*
#             egs*
#           rance*
#           u*
#         ckaert*
#       l
#         l*
#           s*
#             ides*
#           y*
#         aire*
#       rtula*
#       d
#         ing*
#         algo*
#         e*
#           s*
#       malaya*
#         mammals*
#         n*
#         s*
#       ppo
#         griff*
#         campus*
#         drome*
#       g
#         h*
#           e
#             r*
#             st*
#           s*
#           l
#             ands*
#             y*
#         don*
#       s
#         sa*
#         t
#           o
#             r
#               ic*
#                 al*
#                   ly*
#               y*
#                 close*
#             ire*
#             logia*
#           riophoca*
#         pida*
#       bernat
#         ors*
#         i
#           on*
#           ng*
#         e*
#       t*
#         ting*
#       ck
#         ory*
#         son*
#       erarch
#         ies*
#         y*
#       ve*
#         s*
#     wang*
#     t
#       tps*
#       m*
#     kakaborazi*
#     m*
#     bciek*
#     s
#       anda*
#       u*
#       i
#         u*
#         ng*
#     dl*
#     qq*
#     ponkanrazi*
#   i
#     m
#       p
#         o
#           rt*
#             ed*
#             an
#               t*
#               ce*
#           s
#             ing*
#             ed*
#         r
#           ove*
#             d*
#           i
#             nt*
#               rear*
#             sonment*
#         a
#           ct*
#             s*
#           lement*
#           rt*
#         eded*
#         l
#           i
#             es*
#             cations*
#           ying*
#           ant*
#             ing*
#             ation*
#             ed*
#           emented*
#       itat
#         e*
#         ing*
#       m
#         ature*
#         e
#           rsive*
#           diate*
#             ly*
#         itis*
#         une*
#       a
#         g
#           e*
#             s*
#           ined*
#         wbum*
#     n
#       t*
# ...
#         amae*
#         sho*
#         ography*
#       o
#         l*
#           s*
#         k*
#         th*
#           less*
#           ed*
#       hui*
#       n
#         gue*
#           s*
#         s*
#         ni*
#         i*
#       b
#         a*
#           cco*
#           batak*
#         ias*
#       y*
#         s*
#       x
#         oplasm
#           a*
#           osis*
#         ic*
#       tal*
#       g
#         ether*
#         gle*
#     s
#       eng*
#       ubota*
#       imshian*
#       a*
#         ngpo*
#         eio*
#       hering*
#     a
#       o*
#         tao*
#       s
#         te*
#           s*
#         k*
#           s*
#       i*
#         nan*
#         wan*
#         l*
#           s*
#           ed*
#         zong*
#       ctic*
#         s*
#       x
#         i
#           d
#             iinae*
#             e
#               a*
#               rmy*
#           color*
#         o
#           don*
#           n*
#             om
#               y*
#               i
#                 sts*
#                 c*
#         us*
#         a*
#       l
#         l*
#           er*
#         e*
#           s*
#         k*
#         bot*
#       n
#         k*
#         e*
#         g*
#           ling*
#           alunga*
#         aka*
#         ya*
#       hoe*
#       r
#         a*
#         get*
#           s*
#         tu*
#         onga*
#       b
#         oo*
#         erlet*
#         le*
#           s*
#         ard*
#         s*
#       gliabue*
#       y
#         ra*
#         lor*
#       ttaq*
#       p
#         lejung*
#         e
#           worms*
#           ring*
#       k
#         in*
#           g*
#         e*
#           s*
#           n*
#       u
#         ssig*
#         ght*
#       me*
#         sis*
#         d*
#     v*
#     u
#       r
#         moil*
#         n*
#           i
#             ng*
#             p*
#           s*
#           e
#             d*
#             r*
#         key*
#         binal*
#       n
#         nel*
#         dra*
#       bers*
#       an*
#         yuan*
#       sks*
#       omala*
#     y
#       son*
#       p
#         e*
#           s*
#         ical*
#           ly*
#       r
#         rhenolutra*
#         annus*
#       ger*
#     w
#       i
#         gs*
#         tter*
#           s*
#           ing*
#         sting*
#         ce*
#         ns*
#       o*
#       entieth*
#     l
#       apacoya*
#       ingit*
#   u*
#     hlhorn*
#     n
#       l
#         ike*
#           ly*
#         awful*
#         e
#           ashed*
#           ss*
#       regulated*
#       e
#         xcited*
#         do*
#         sco*
#       naturally*
#       c
#         ertain*
#         lear*
#         o
#           mmon*
#           ntrolled*
#         ia*
#       i
#         corn*
#         form*
#         v*
#           ers
#             ity*
#             ally*
#         que*
#           ly*
#         t*
#           s*
#           ed*
#         on*
#       d
#         ocumented*
#         e
#           r
#             w
#               eight*
#               ater*
#               orld*
#             taken*
#             neath*
#             fur*
#             g
#               o*
#                 es*
#               round*
#             coat*
#             estimated*
#             lying*
#             st
#               and*
#                 ing*
#               or
#                 eys*
#                 y*
#             developed*
#           termined*
#           veloped*
#         i
#           fferentiated*
#           sturbed*
#       g
#         ulate*
#           s*
#           like*
#         av
#           a*
#             esis*
#             n*
#           ensis*
#         er*
#       predictable*
#       marked*
#       forested*
#       a*
#         vailable*
#         ble*
#       usual*
#         ly*
#       known*
#       ta
#         med*
#         nned*
#       s
#         ourced*
#         uccessful*
#       veil
#         s*
#         ing*
#       he
#         ard*
#         raldic*
#     r
#       s*
#         u
#           am*
#           ma*
#           s*
#             linnaeus*
#           la*
#         i
#           d*
#             a*
#               e*
#                 g*
#             s*
#           n
#             us*
#             e*
#             ae*
#         a*
#           r*
#             i*
#           v
#             us*
#             inae*
#         oid*
#           ea*
#       a
#         nia*
#         m*
#       va*
#       ban*
#         ization*
#       o
#         pathogenic*
#         cyon*
#       in
#         e*
#         a
#           ting*
#           ry*
#       ea*
#       l*
#         download*
#     s*
#       ing*
#       e*
#         s*
#         r*
#           s*
#         d*
#         less*
#         ful*
#       s
#         r*
#         uri*
#           cus*
#       a*
#       gs*
#       u
#         al*
#           ly*
#         rping*
#     b
#       btti*
#       iquitous*
#       c*
#     p
#       date*
#         s*
#         d*
#       on*
#       ec*
#       right*
#       land*
#       per*
#     t
#       karsh*
#       ah*
#       iliz
#         ing*
#         ed*
#         ation*
#       c*
#       tam*
#       e
#         p*
#         r
#           ine*
#           us*
#     l
#       ev*
#       traviolet*
#       na*
#     g
#       arte*
#       yen*
#     m
#       brella*
#       ami*
#     dder*
#     k*
#       rainetz*
#     a*
#   j*
#     o
#       tt*
#       urnal*
#         s*
#       d
#         ie*
#         y*
#       motsangkha*
#       r
#         genson*
#         dan*
#       s
#         e*
#           p*
#           f*
#         h
#           i*
#           ua*
#         ip*
#       ann
#         e*
#         a*
#       i
#         m*
#         nts*
#       hn*
#         s*
#           on*
#           ton*
#             i*
#       n*
#         a
#           than*
#           s*
#           h*
#         es*
#       e*
#         l*
#     i*
#       a*
#         n*
#           wen*
#           g*
#             uo*
#           jun*
#         o*
#         jin*
#       n*
#         dong*
#         chu*
#         g*
#           yi*
#         yan*
#           g*
#       e*
#         zi*
#       m*
#         enez*
#       gme*
#     a
#       c*
#         ques*
#         k*
#           ets*
#           al*
#           son*
#             i*
#         ob*
#           ita*
#           s*
#       w*
#         s*
#         bone*
#           s*
#       il*
#       n
#         ke*
#         is*
#         ene*
#         uary*
#         s
#           en*
#           son*
#       van*
#         ensis*
#         ica*
#       mes*
#       blonski*
#       r
#         s*
#         ed*
#       guar*
#         undi*
#         s*
#       eger*
#       pan*
#         ese*
#       y*
#         apal*
#     u
#       batus*
#       n*
#         iper*
#         hu*
#         g*
#           le*
#         e*
#       dy*
#       an*
#       venile*
#       mp*
#         ing*
#       l
#         ia*
#         y*
#       sti
#         n*
#         ce*
#     biomech*
#     e
#       ou*
#       pson*
#       n
#         aensis*
#         nifer*
#         ssen*
#       r
#         sey*
#         rold*
#         doni*
#       ss
#         en*
#         i
#           e*
#           ca*
#       f
#         fre
#           y*
#           e*
#         e*
#       anne*
#       t*
#       b*
#     h
#       ered*
#       u*
#       a*
#     r*
#       d*
#     wmg*
#     m
#       or*
#       ammal*
#     nawali*
#     z
#       ar*
#       o*
#     qs*
#     s
#       tor*
#       ames*
#   w*
#     i
#       l
#         frid*
#         son*
#         d*
#           e*
#             r*
#               ness*
#           cat*
#           fire*
#           t*
#           l*
#             ife*
#               information*
#         ey*
#         l
#           ard*
#           erslev*
#           iam*
#             s*
#               on*
#         helm*
#       sconsin*
#       gen*
#       ig*
#       n
#         ged*
#         e*
#         ni
#           peg*
#           e*
#         t
#           er*
#             ing*
#           le*
#       edii*
#       ckersham*
#       k
#         i
#           data*
#             wikipedia*
#             taxonbars*
#             good*
#             articles*
#           newstaxa*
#           media*
#           species*
#           quote*
#           pedia*
#             contact*
#         tionary*
#       d
#         e*
#           spread*
#           ly*
#           r*
#         th*
#       t
#         h
#           in*
#           er
#             s*
#             ington*
#           out*
#         ness*
#         t
#           mer*
#           ekindt*
#     o
#       ken*
#       jda*
#       ng*
#       r
#         d*
#           ed*
#           s*
#         k*
#           s*
#           ing*
#         n*
#         ld*
#           wide*
#           grizzly*
#         m*
#           s*
#         e*
#         s
#           hip*
#           t*
#         thy*
#       zencraft*
#       l
#         f*
#           sangel*
#         ve
#           s*
#           r
#             ine*
#             ton*
#         lebaeki*
#         ong*
#       o
#         d*
#           cock*
#           r
#             offe*
#             uff*
#           lands*
#           wose*
#           s*
#           burne*
#         fing*
#         lly*
#       hl*
#       m
#         en*
#         b*
#           well*
#         an*
#       u
#         nd*
#           ed*
#         ld*
#     a
#       r*
#         e*
#         m*
#           s*
#           er*
#           th*
#           ing*
#         n*
#           er*
#           ing*
#         r
#           ior*
#           en*
#         d*
#       t
#         ch*
#           ing*
#           es*
#         ts*
#         er*
#           colour*
#           lily*
#           fowl*
#           ton*
#         ik*
#       l
#         t*
#           er*
#         dheim*
#           ursoideahidden*
#         l*
#           ace*
#         k*
#           er*
#           ing*
#         rus*
#           es*
#       n*
#         der*
#           s*
#         g*
#           e*
#           lang*
#           chu
#             ck*
#             k*
#         jun*
#         t
#           ing*
#           ed*
#       it*
#         ed*
#         s*
#       k
#         kinen*
#         e*
#           s*
#       de*
#       y*
#         s*
#         ne*
#         back*
#       ve
#         lengths*
#         s*
#       ck*
#       s
#         hington*
#           post*
#         te*
#         ps*
#       fted*
#       xy*
#       ugh*
#       bakken*
#       gner*
#     e
#       t*
#         land*
#         zel*
#       l
#         l*
#         c
#           h*
#             ii*
#           omes*
#         fare*
#       a
#         r*
#           ing*
#         sel*
#           words*
#           s*
#         k*
#           er*
#         ver*
#         ther*
#         ned*
#         lthy*
#       dd
#         ings*
#         ell*
#           ii*
#       b*
#         archive*
#         s*
#           ite*
#       n*
#         ke*
#         l
#           ei*
#           iang*
#         wen*
#         t*
#       mmer*
#       i*
#         g
#           l*
#           h*
#             ed*
#             t*
#             s*
#             ing*
#         l*
#         ssengruber*
#         rui*
#         h
#           ua*
#           ong*
#       e
#         ks*
#         rman*
#       s
#         t*
#           ern*
#             most*
#           all*
#         ley*
#     h
#       i
#         skers*
#         psnade*
#         t
#           e*
#             side*
#             b
#               eam*
#               ark*
#           ish*
#       yte*
#       e
#         never*
#         at*
#         ther*
#         re
#           ver*
#           as*
#       b*
#       o
#         se*
#         le*
#       al
#         e*
#           rs*
#           s*
#         ing*
#       c*
#     r
#       o
#         e*
#         te*
#       e
#         ath*
#         stl
#           ing*
#           er*
#       i
#         nkled*
#         t
#           ings*
#           ten*
#           er*
#         st*
#     y*
#       oming*
#       vern*
#     w
#       w*
#       f*
#         china*
#     jhg*
#     sb*
#     m
#       sbga*
#       on*
#     u*
#       nn*
#       rsig*
#   y
#     le*
#     np*
#     u*
#       ri*
#       shania*
#       kon*
#       n*
#         nan*
#       liy*
#       e*
#         yue*
#         n*
#       an*
#     e
#       ung*
#       t*
#         i*
#       l
#         low*
#           stone*
#             park*
#           ish*
#         e*
#       soensis*
#       ar*
#         s*
#         book*
#         l
#           y*
#           ing*
#             s*
#     o
#       u
#         ng*
#           er*
#         le*
#         you*
#       n
#         g*
#           g
#             uo*
#             ang*
#           le*
#         zon*
#         ezawa*
#       ccoz*
#       rk*
#       s
#         emite*
#         hida*
#       mi*
#       g
#         anand*
#         i*
#     i*
#       hua*
#       e*
#         ld*
#       n*
#         qi*
#         g*
#           jie*
#       annis*
#       sheng*
#       bo*
#       la*
#     a*
#       o*
#         wu*
#       manaka*
#       ping*
#       r
#         lung*
#         d*
#           s*
#         mey*
#       n*
#         g*
#       bsley*
#       le*
#       gouaroundi*
#     bp*
#     mpev*
#   k*
#     i
#       n
#         ometaxia*
#         d
#           berg*
#           aichi*
#         g*
#           dom*
#           sley*
#         kajou*
#         ematic*
#       s
#         leika*
#         t
#           ler*
#           chinski*
#       d
#         n
#           eys*
#           apping*
#         syouth*
#       r
#         illova*
#         k*
#       t*
#       m*
#       l
#         l*
#           e
#             d*
#             r*
#               s*
#           s*
#           ing*
#         o
#           metres*
#           grams*
#     o
#       u*
#         ba*
#       e
#         ppel*
#         hler*
#       tzebue*
#       chnev*
#       h*
#         shima*
#       l
#         ponomos*
#         i*
#         okotronis*
#         ter*
#         enosky*
#       vr*
#       rea*
#         n*
#           s*
#       s
#         intsev*
#         tyr
#           ya*
#           ia*
#       k*
#       ju*
#       d
#         kod*
#         iak*
#       n
#         g*
#         ungs*
#     e*
#       e
#         nest*
#         p*
#           s*
#           ing*
#       y*
#         es*
#         word*
#         thong*
#       l*
#         ava*
#         l
#           y*
#           e
#             rt*
#             y*
#       s
#         sler*
#         a*
#           gake*
#       pt*
#       n
#         ai*
#         yalutra*
#         n
#           edy*
#           ing*
#         tucky*
#         dall*
#       ith*
#       r
#         atin*
#         mode*
#           i*
#         ley*
#         ry*
#       a
#         y*
#         rns*
#         ting*
#       ddie*
#       vin*
#       mp*
#     a*
#       r
#         en*
#         ine*
#         a*
#           manlidis*
#         ki*
#         y
#           n*
#           otype*
#         hu*
#       l
#         evala*
#         aallit*
#         i
#           kot*
#           mantan*
#       n
#         g*
#           chenjunga*
#           aroo*
#         sas*
#         e*
#         chenjunga*
#         del*
#         a
#           gawa*
#           naskis*
#       t
#         rina*
#         h
#           leen*
#           iah*
#           erine*
#       i*
#         feng*
#       ktovik*
#       m
#         eng*
#         chatka*
#           n*
#         al*
#       s
#         worm*
#         son*
#       p
#         p*
#           elhof*
#         oor*
#       czensky*
#     r
#       uuk*
#       e
#         sky*
#         tzoiarctos*
#       aus
#         e*
#         man*
#       isti
#         na*
#         jan*
#       on
#         e*
#         k*
#     u
#       n
#         z*
#         g*
#         war*
#         a*
#       ma
#         r*
#         matsuri*
#       s
#         imanse*
#         ak*
#         h*
#       iu*
#       hni*
#       rten*
#       t
#         chin*
#         schera*
#       bi
#         ski*
#         ak*
#     y
#       rgyzstan*
#       naston*
#       ongnosla*
#     g*
#     b*
#     l
#       assert*
#       e
#         bsiella*
#         ptoparasites*
#         iman*
#       inka*
#     j*
#       os*
#     n
#       o
#         xville*
#         w*
#           ing*
#           n*
#           ledge*
#         ck*
#         t*
#           t*
#             nerus*
#           s*
#         pf*
#       ife*
#       ut*
#       auer*
#     wak
#       iutl*
#       wa*
#     h
#       a
#         n*
#           gchendzonga*
#           al*
#         ptad*
#         t
#           iwara*
#           tab*
#           ri*
#       esar*
#       z*
#     m*
#     c
#       al*
#       rg*
#     s*
#   x*
#     i*
#       x*
#       n*
#         qiang*
#         hua*
#       a
#         ng*
#           yu*
#           hui*
#           ru*
#         o*
#           xiang*
#             ling*
#           ping*
#           dong*
#           li*
#           feng*
#       ong*
#       e*
#       lite*
#       u*
#       i*
#         i*
#     u*
#       an*
#       e*
#         feng*
#         yang*
#       long*
#     v*
#     xix*
#     en
#       ogale*
#       ictis*
#   q*
#     u*
#       e
#         st*
#           ions*
#         en*
#         bec*
#         rc
#           y*
#           us*
#         ntin*
#       a
#         il*
#         n*
#           fei*
#           ti
#             t
#               y*
#               ies*
#             fying*
#         druped
#           al*
#           s*
#         r
#           ter*
#             s*
#             ing*
#           ry*
#         lit
#           y*
#           ative*
#         t
#           re*
#             foil*
#           ernary*
#       i
#         ntavalle*
#         gley*
#         te*
#         et*
#           ly*
#         ckly*
#       otations*
#       bi*
#     i*
#       lin*
#       an*
#         g*
#       onglai*
#       n*
#         ling*
#           ensis*
#         g
#           le*
#           yue*
#       u*
#     aunaq*
#     e*
#     r*
#       es*

# %% [markdown]
# ## Search and ranking

# %% [markdown]
# ### Function for search and ranking

# %%
def multiple_search_webpages(searchword, vocab_trie, inverted_indices,filter_words):
    string_list = re.findall(r'\b[a-zA-Z]+\b', searchword.lower()) # preprocess
    filtered_string_list = [word for word in string_list if word not in filter_words]
    print(f"input: {searchword} \n")
    
    results_list = []
    intersected_pages = None  # store common webpages
    
    for searchword in filtered_string_list:
        if vocab_trie.search_function(searchword):  # check if word is in trie
            pages = inverted_indices.get(searchword, [])  # set the webpages from word with inverted index
            sorted_pages = sorted(pages, key=lambda string_in: int(string_in.split()[-2]), reverse=True)  # sort by no. of occurences
            print(f"'{searchword}' found in these pages: \n")
            for i in sorted_pages:  # Print the ranked results
                print(i)
            print('\n')
            if len(filtered_string_list)>1: # check for intersection of webpages, this will give common terms
                trimmed_pages = {page.split("html")[0] + "html" for page in sorted_pages}
                if intersected_pages is None:
                    intersected_pages = trimmed_pages
                else:
                    intersected_pages &= trimmed_pages 
        else:
            print(f"Word '{searchword}' is not in vocabulary.")  # word is not in trie
    
    if len(filtered_string_list)>1: # print common webpages if any
        if intersected_pages:
            print("\nIntersection of results for all words:\n")
            for page in intersected_pages:
                print(page)
        else:
            print("\nNo common pages found for all words.")

# %% [markdown]
# ### Sample searches

# %%
searchword='pandas'
multiple_search_webpages(searchword, vocab_trie, inverted_indices,filter_words)
# Out:
# input: pandas
#
# 'pandas' found in these pages:
#
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Giant_panda _Wikipedia.html 123 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Red_panda_Wikipedia.html 45 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Bear_Wikipedia.html 12 instances

# %%
searchword='potato'
multiple_search_webpages(searchword, vocab_trie, inverted_indices,filter_words)
# Out:
# input: potato
#
# Word 'potato' is not in vocabulary.

# %%
searchword='extinction of pandas'
multiple_search_webpages(searchword, vocab_trie, inverted_indices,filter_words)
# Out:
# input: extinction of pandas
#
# 'extinction' found in these pages:
#
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Brown_bear_ Wikipedia.html 5 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Giant_panda _Wikipedia.html 1 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\American_black_bear_Wikipedia.html 1 instances
#
#
# 'pandas' found in these pages:
#
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Giant_panda _Wikipedia.html 123 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Red_panda_Wikipedia.html 45 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Bear_Wikipedia.html 12 instances
#
#
#
# Intersection of results for all words:
#
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Giant_panda _Wikipedia.html

# %%
searchword='bear eating trash'
multiple_search_webpages(searchword, vocab_trie, inverted_indices,filter_words)
# Out:
# input: bear eating trash
#
# 'bear' found in these pages:
#
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Brown_bear_ Wikipedia.html 324 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\American_black_bear_Wikipedia.html 262 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Polar_bear_Wikipedia.html 233 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Bear_Wikipedia.html 214 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Giant_panda _Wikipedia.html 38 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Red_panda_Wikipedia.html 9 instances
#
#
# 'eating' found in these pages:
#
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Giant_panda _Wikipedia.html 7 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\American_black_bear_Wikipedia.html 6 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Bear_Wikipedia.html 6 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Red_panda_Wikipedia.html 5 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Polar_bear_Wikipedia.html 5 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Brown_bear_ Wikipedia.html 4 instances
#
#
# 'trash' found in these pages:
#
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Brown_bear_ Wikipedia.html 1 instances
#
#
#
# Intersection of results for all words:
#
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Brown_bear_ Wikipedia.html

# %%
searchword='bear found in china'
multiple_search_webpages(searchword, vocab_trie, inverted_indices,filter_words)
# Out:
# input: bear found in china
#
# 'bear' found in these pages:
#
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Brown_bear_ Wikipedia.html 324 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\American_black_bear_Wikipedia.html 262 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Polar_bear_Wikipedia.html 233 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Bear_Wikipedia.html 214 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Giant_panda _Wikipedia.html 38 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Red_panda_Wikipedia.html 9 instances
#
#
# 'found' found in these pages:
#
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\American_black_bear_Wikipedia.html 25 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Polar_bear_Wikipedia.html 13 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Bear_Wikipedia.html 12 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Red_panda_Wikipedia.html 12 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Brown_bear_ Wikipedia.html 11 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Giant_panda _Wikipedia.html 9 instances
#
#
# 'china' found in these pages:
#
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Giant_panda _Wikipedia.html 61 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Red_panda_Wikipedia.html 24 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Brown_bear_ Wikipedia.html 4 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Bear_Wikipedia.html 3 instances
#
#
#
# Intersection of results for all words:
#
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Red_panda_Wikipedia.html
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Giant_panda _Wikipedia.html
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Brown_bear_ Wikipedia.html
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Bear_Wikipedia.html

# %%
searchword='which bear stays at north pole?'
multiple_search_webpages(searchword, vocab_trie, inverted_indices,filter_words)
# Out:
# input: which bear stays at north pole?
#
# 'bear' found in these pages:
#
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Brown_bear_ Wikipedia.html 324 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\American_black_bear_Wikipedia.html 262 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Polar_bear_Wikipedia.html 233 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Bear_Wikipedia.html 214 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Giant_panda _Wikipedia.html 38 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Red_panda_Wikipedia.html 9 instances
#
#
# 'stays' found in these pages:
#
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\American_black_bear_Wikipedia.html 1 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Polar_bear_Wikipedia.html 1 instances
#
#
# 'north' found in these pages:
#
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\American_black_bear_Wikipedia.html 49 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Brown_bear_ Wikipedia.html 39 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Bear_Wikipedia.html 30 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Polar_bear_Wikipedia.html 13 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Red_panda_Wikipedia.html 12 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Giant_panda _Wikipedia.html 1 instances
#
#
# 'pole' found in these pages:
#
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Polar_bear_Wikipedia.html 3 instances
#
#
#
# Intersection of results for all words:
#
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Polar_bear_Wikipedia.html

# %% [markdown]
# ## Textbox for search

# %%
search = input("Search: \t")
multiple_search_webpages(search, vocab_trie, inverted_indices,filter_words)
# Out:
# Search: 	bear in alaska
# input: bear in alaska
#
# 'bear' found in these pages:
#
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Brown_bear_ Wikipedia.html 324 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\American_black_bear_Wikipedia.html 262 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Polar_bear_Wikipedia.html 233 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Bear_Wikipedia.html 214 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Giant_panda _Wikipedia.html 38 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Red_panda_Wikipedia.html 9 instances
#
#
# 'alaska' found in these pages:
#
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Brown_bear_ Wikipedia.html 18 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\American_black_bear_Wikipedia.html 16 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Polar_bear_Wikipedia.html 12 instances
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Bear_Wikipedia.html 3 instances
#
#
#
# Intersection of results for all words:
#
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\American_black_bear_Wikipedia.html
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Brown_bear_ Wikipedia.html
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Bear_Wikipedia.html
# C:/Users/kanad/Documents/CS 600/Project/HTML_files\Polar_bear_Wikipedia.html
